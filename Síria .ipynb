# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
sns.set_theme(style='darkgrid')
plt.rc('figure', figsize=(14, 6))
import folium

# %%
dados = pd.read_csv('dados/Registered Syrian Refugees by Date.csv', sep=';')
dados
# Out:
#            sep=   Unnamed: 1
# 0     data_date  individuals
# 1    2012-01-15         9500
# 2    2012-02-29        10658
# 3    2012-04-18        23955
# 4    2012-04-23        23702
# ..          ...          ...
# 638         NaN          NaN
# 639         NaN          NaN
# 640         NaN          NaN
# 641         NaN          NaN
# 642         NaN          NaN
#
# [643 rows x 2 columns]

# %% [markdown]
# ### Testando a biblioteca Folium

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\henri\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: requests in c:\users\henri\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\henri\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: numpy in c:\users\henri\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: jinja2>=2.9 in c:\users\henri\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\henri\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Coordenadas dos pontos
lats = np.random.normal(36, 1, 100) # latitude
lons = np.random.normal(37, 1, 100) # longitude

# Cria um mapa centrado nas coordenadas médias
map = folium.Map(location=[np.mean(lats), np.mean(lons)], zoom_start=8)

# Adiciona marcadores para cada ponto
for lat, lon in zip(lats, lons):
    folium.Marker(location=[lat, lon]).add_to(map)

# Mostra o mapa
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aee3ec3efc4692c78749a00a3c4ebc3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aee3ec3efc4692c78749a00a3c4ebc3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aee3ec3efc4692c78749a00a3c4ebc3f = L.map(
#                 &quot;map_aee3ec3efc4692c78749a00a3c4ebc3f&quot;,
#                 {
#                     center: [35.78279501629108, 37.114961558999155],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b18365019889014b4d2c0802defaafb8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_59b1e5bbd8bfc6ce860a543f5e56239d = L.marker(
#                 [38.0930610344657, 37.130038100338396],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_0272f9623e3654536bd10f7a64df3dc9 = L.marker(
#                 [36.23775300543176, 37.75760872098891],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_c6fb047a1685f1ef4eac3bfb8b5e5ff5 = L.marker(
#                 [34.84620464737542, 39.132734263267494],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_668e3c4d005aaf4ea0eb2eb85b5b558e = L.marker(
#                 [37.131867886825745, 37.97844189303913],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_8869ad2a8850ad5a1ccc3f2937203332 = L.marker(
#                 [36.59264537391093, 36.66206737547796],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_1880a825cb126fa73b1c5275d6c354f5 = L.marker(
#                 [34.42305804541204, 38.23655287767007],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_224bfebadbc401ca7c03b4ccc7abe97c = L.marker(
#                 [35.50985307723709, 36.308381657320595],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_ff2ceeed4cc28b23b20fd3d799b541f4 = L.marker(
#                 [36.20815021054196, 37.661133113956694],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_a87a7c3646f9f95c053737462371b0b5 = L.marker(
#                 [35.9739467149848, 37.843831993174454],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_9d71b896ad6232ba1325cc6e3dd482af = L.marker(
#                 [36.12381312136641, 37.22321586486371],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_5a79f268e88b6997381531e83a8ed965 = L.marker(
#                 [34.78375596432741, 35.96363704985434],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_98041ae029c193b7145ad35b14715995 = L.marker(
#                 [36.6526899604238, 37.31469455124885],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_44241d25333f33a021f1b69cf0139c14 = L.marker(
#                 [35.024655863517225, 36.17721686865646],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_4b9504f5f64150a034239ed67c071895 = L.marker(
#                 [36.24746838891497, 37.990880843769816],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_f6c4c7d16e73c06c1bfa635052ad29b2 = L.marker(
#                 [35.52911935175113, 37.568640383814056],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_1031c984672ca6dc9414118ecc47faee = L.marker(
#                 [36.17556040959866, 36.391539243126104],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_19cd9ade6ca8a5b3f1124127f5095831 = L.marker(
#                 [36.86137542456329, 38.895300271441485],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_6b1b53a3603f47f0fed079726948a04e = L.marker(
#                 [35.32014502363053, 35.65819868628872],
#                 {}
#             ).addTo(map_aee3ec3efc4692c78749a00a3c4ebc3f);
#
#
#             var marker_9bed912a27610d0c316c5656811cfe3b = L.marker(
#                 [35.27953674451935, 36.203250373163364],
#                 {}
#             ).addTo(map_aee3

# %%
dados1= pd.read_csv('dados/hotosm_tur_destroyed_buildings_polygons_csv.csv')
dados1
# Out:
#           osm_id building damage_date addr_street destroyed_building  \
# 0     1147164787      NaN  2023-02-06         NaN                yes
# 1     1147166052      NaN  2023-02-06         NaN                yes
# 2     1147170022      NaN  2023-02-06         NaN                yes
# 3     1147174340      NaN  2023-02-06         NaN                yes
# 4     1147174347      NaN  2023-02-06         NaN                yes
# ...          ...      ...         ...         ...                ...
# 3301  1139190966      NaN  2023-02-06         NaN                yes
# 3302  1139524307      NaN  2023-02-06         NaN                yes
# 3303  1139658748      NaN  2023-02-06         NaN                yes
# 3304  1139274714      NaN  2023-02-06         NaN                yes
# 3305  1138927169      NaN  2023-02-06         NaN                yes
#
#              source  addr_full      damage_event addr_city addr_housenumber  \
# 0     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 1     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 2     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 3     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 4     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# ...             ...        ...               ...       ...              ...
# 3301          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
# 3302          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
# 3303          cscrc        NaN  #TürkiyeEQ060223       NaN              NaN
# 3304          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
# 3305          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
#
#      name damage_type  longitude   latitude geom_type
# 0     NaN  earthquake  36.365865  36.472146   POLYGON
# 1     NaN  earthquake  36.352694  36.493447   POLYGON
# 2     NaN  earthquake  36.353101  36.491821   POLYGON
# 3     NaN  earthquake  36.358288  36.496162   POLYGON
# 4     NaN  earthquake  36.358789  36.496386   POLYGON
# ...   ...         ...        ...        ...       ...
# 3301  NaN  earthquake  36.630427  37.022934   POLYGON
# 3302  NaN  earthquake  36.629054  37.025857   POLYGON
# 3303  NaN  earthquake  36.629579  37.024958   POLYGON
# 3304  NaN  earthquake  36.631257  37.027352   POLYGON
# 3305  NaN  earthquake  36.630033  37.018256   POLYGON
#
# [3306 rows x 15 columns]

# %% [markdown]
# ### Plotando com os dados de edificios destruidos na Turquia

# %%
longi = dados1['longitude']
lati = dados1['latitude']

# %%
lats = lati # latitude
lons = longi # longitude

# Cria um mapa centrado nas coordenadas médias
map = folium.Map(location=[np.mean(lats), np.mean(lons)], zoom_start=9)

folium.TileLayer('cartodbpositron').add_to(map)
folium.TileLayer('Stamen Terrain').add_to(map)
folium.TileLayer('stamentoner').add_to(map)

# Adiciona marcadores para cada ponto
for lat, lon in zip(lats, lons):
    folium.Marker(location=[lat, lon], icon=folium.Icon(color = "blue", radius=50, icon="flag")).add_to(map)

folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df2dab9d09054371b6b991ed34fa45a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df2dab9d09054371b6b991ed34fa45a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df2dab9d09054371b6b991ed34fa45a4 = L.map(
#                 &quot;map_df2dab9d09054371b6b991ed34fa45a4&quot;,
#                 {
#                     center: [37.01835326421933, 36.818975096105696],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffe82f4d5a77c3b2109aff02ecb8df60 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_df2dab9d09054371b6b991ed34fa45a4);
#
#
#             var tile_layer_0dce86c45ca0c8690f4735fe34387785 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_df2dab9d09054371b6b991ed34fa45a4);
#
#
#             var tile_layer_dfffd8e495ed85cb97970757b30fb954 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_df2dab9d09054371b6b991ed34fa45a4);
#
#
#             var tile_layer_1ca7945afce2ab7b373af4c560baae98 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_df2dab9d09054371b6b991ed34fa45a4);
#
#
#             var marker_b8816e4635997f65897e684bb4b902dc = L.marker(
#                 [36.4721463720923, 36.3658651662668],
#                 {}
#             ).addTo(map_df2dab9d09054371b6b991ed34fa45a4);
#
#
#             var icon_7f9b43528e790c9fb3b850f65c5f4e5b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;radius&quot;: 50}
#             );
#             marker_b8816e4635997f65897e684bb4b902dc.setIcon(icon_7f9b43528e790c9fb3b850f65c5f4e5b);
#
#
#             var marker_9988370b4c2991edd9379bb748a7786a = L.marker(
#                 [36.49344725, 36.3526944],
#                 {}
#             ).addTo(map_df2dab9d09054371b6b991ed34fa45a4);
#
#
#             var icon_651eccda795d3df2b25744a0a7900f0b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;
