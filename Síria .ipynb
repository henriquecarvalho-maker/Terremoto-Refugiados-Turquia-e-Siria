# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
sns.set_theme(style='darkgrid')
plt.rc('figure', figsize=(14, 6))
import folium

# %%
dados = pd.read_csv('dados/Registered Syrian Refugees by Date.csv', sep=';')
dados
# Out:
#            sep=   Unnamed: 1
# 0     data_date  individuals
# 1    2012-01-15         9500
# 2    2012-02-29        10658
# 3    2012-04-18        23955
# 4    2012-04-23        23702
# ..          ...          ...
# 638         NaN          NaN
# 639         NaN          NaN
# 640         NaN          NaN
# 641         NaN          NaN
# 642         NaN          NaN
#
# [643 rows x 2 columns]

# %% [markdown]
# ### Testando a biblioteca Folium

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\henri\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\henri\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in c:\users\henri\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\henri\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: numpy in c:\users\henri\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\henri\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Coordenadas dos pontos
lats = np.random.normal(36, 1, 100) # latitude
lons = np.random.normal(37, 1, 100) # longitude

# Cria um mapa centrado nas coordenadas médias
map = folium.Map(location=[np.mean(lats), np.mean(lons)], zoom_start=8)

# Adiciona marcadores para cada ponto
for lat, lon in zip(lats, lons):
    folium.Marker(location=[lat, lon]).add_to(map)

# Mostra o mapa
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbe8a9b30c838ae03293f6ef25a631ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbe8a9b30c838ae03293f6ef25a631ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbe8a9b30c838ae03293f6ef25a631ad = L.map(
#                 &quot;map_bbe8a9b30c838ae03293f6ef25a631ad&quot;,
#                 {
#                     center: [35.98158688313729, 37.12383936465768],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dec857f51651d607b0a2131a26be240b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_632914e57c28abf3fdd630e45ac46eff = L.marker(
#                 [35.24945524197598, 36.949855096957926],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_bb0eca734f52b10c19218592f322ea77 = L.marker(
#                 [37.032761882408, 38.28730799461024],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_f35165fb537dda6d4ac62d03eb55371a = L.marker(
#                 [35.2317271420455, 36.45605261662773],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_8574634395fd106a4bfc0809199ac246 = L.marker(
#                 [37.75728199538314, 38.79089494944782],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_49dd0b81e3af026216f775e943edc87f = L.marker(
#                 [34.918918128577495, 35.89800907904642],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_e862a2a3dfd924ffc7ca4a22382d28ae = L.marker(
#                 [36.66455237472589, 36.38531958381064],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_e0039e17b1f4f827325baed3b86ce514 = L.marker(
#                 [35.42725854737262, 39.11443486913531],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_7753b4abc7f97bdaa87e0687a58f9af6 = L.marker(
#                 [36.98218599710674, 37.30117791478885],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_890a7e73484e3b4755f1b4fcc05e25cd = L.marker(
#                 [34.511766592108714, 36.865988508413174],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_9286b9fd1a1c8bc07c8fdcb9a404f513 = L.marker(
#                 [35.44566121608956, 37.509613310183596],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_9c17d208313f8698b030528de59400f4 = L.marker(
#                 [34.888130234736074, 36.51722438681538],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_c9285477e2eeb10ec8f687a3866bf351 = L.marker(
#                 [35.802822226630234, 36.34753888002258],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_ae9acee2d5d1e84750639d0d259ab389 = L.marker(
#                 [36.433233235431246, 36.354905870776506],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_e0c0827585941bd2c0fc8d8643c3b385 = L.marker(
#                 [36.046754320406976, 36.825343882086536],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_474473651b9947cafa2b88f84d36cac6 = L.marker(
#                 [35.39083630612849, 36.79953613147793],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_e04cddb975ba9bae136b3fe3b19bbe26 = L.marker(
#                 [35.36663637112329, 35.787891825092615],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_515b66c6156008297c7da37941dd241b = L.marker(
#                 [33.633258843845866, 37.66996659435601],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_00d3cd0e6111c45104aab3e9645365bb = L.marker(
#                 [36.76089784384909, 36.23681192247981],
#                 {}
#             ).addTo(map_bbe8a9b30c838ae03293f6ef25a631ad);
#
#
#             var marker_aee284ea438caacdc7fcbc81e32266d6 = L.marker(
#                 [35.96265383188058, 36.21899588585766],
#                 {}
#             ).addTo(map_bbe8

# %%
dados1= pd.read_csv('dados/hotosm_tur_destroyed_buildings_polygons_csv.csv')
dados1
# Out:
#           osm_id building damage_date addr_street destroyed_building  \
# 0     1147164787      NaN  2023-02-06         NaN                yes
# 1     1147166052      NaN  2023-02-06         NaN                yes
# 2     1147170022      NaN  2023-02-06         NaN                yes
# 3     1147174340      NaN  2023-02-06         NaN                yes
# 4     1147174347      NaN  2023-02-06         NaN                yes
# ...          ...      ...         ...         ...                ...
# 3301  1139190966      NaN  2023-02-06         NaN                yes
# 3302  1139524307      NaN  2023-02-06         NaN                yes
# 3303  1139658748      NaN  2023-02-06         NaN                yes
# 3304  1139274714      NaN  2023-02-06         NaN                yes
# 3305  1138927169      NaN  2023-02-06         NaN                yes
#
#              source  addr_full      damage_event addr_city addr_housenumber  \
# 0     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 1     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 2     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 3     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 4     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# ...             ...        ...               ...       ...              ...
# 3301          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
# 3302          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
# 3303          cscrc        NaN  #TürkiyeEQ060223       NaN              NaN
# 3304          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
# 3305          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
#
#      name damage_type  longitude   latitude geom_type
# 0     NaN  earthquake  36.365865  36.472146   POLYGON
# 1     NaN  earthquake  36.352694  36.493447   POLYGON
# 2     NaN  earthquake  36.353101  36.491821   POLYGON
# 3     NaN  earthquake  36.358288  36.496162   POLYGON
# 4     NaN  earthquake  36.358789  36.496386   POLYGON
# ...   ...         ...        ...        ...       ...
# 3301  NaN  earthquake  36.630427  37.022934   POLYGON
# 3302  NaN  earthquake  36.629054  37.025857   POLYGON
# 3303  NaN  earthquake  36.629579  37.024958   POLYGON
# 3304  NaN  earthquake  36.631257  37.027352   POLYGON
# 3305  NaN  earthquake  36.630033  37.018256   POLYGON
#
# [3306 rows x 15 columns]

# %% [markdown]
# ### Plotando com os dados de edificios destruidos na Turquia

# %%
longi = dados1['longitude']
lati = dados1['latitude']

# %%
lats = lati # latitude
lons = longi # longitude

# Cria um mapa centrado nas coordenadas médias
map = folium.Map(location=[np.mean(lats), np.mean(lons)], zoom_start=9)

folium.TileLayer('cartodbpositron').add_to(map)
folium.TileLayer('Stamen Terrain').add_to(map)
folium.TileLayer('stamentoner').add_to(map)

# Adiciona marcadores para cada ponto
for lat, lon in zip(lats, lons):
    folium.Marker(location=[lat, lon], icon=folium.Icon(color = "blue", radius=50, icon="flag")).add_to(map)

folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e87c83ec0e6228061b971e6dce4f9889 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e87c83ec0e6228061b971e6dce4f9889&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e87c83ec0e6228061b971e6dce4f9889 = L.map(
#                 &quot;map_e87c83ec0e6228061b971e6dce4f9889&quot;,
#                 {
#                     center: [37.01835326421933, 36.818975096105696],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8980d3e1eef8124475fb16fb7cf11b57 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e87c83ec0e6228061b971e6dce4f9889);
#
#
#             var tile_layer_9f837dd3b6f3d43e17a2c24fca2bb636 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e87c83ec0e6228061b971e6dce4f9889);
#
#
#             var tile_layer_5d3d4984ac658ec05410f536bb694f40 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e87c83ec0e6228061b971e6dce4f9889);
#
#
#             var tile_layer_1eb78667bbd1060ff960a7e71e0246c2 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e87c83ec0e6228061b971e6dce4f9889);
#
#
#             var marker_abed4b36223f95b3d9879f3b3d2c6812 = L.marker(
#                 [36.4721463720923, 36.3658651662668],
#                 {}
#             ).addTo(map_e87c83ec0e6228061b971e6dce4f9889);
#
#
#             var icon_fe85bc72dbb7fc705b8fdac787d42d13 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;radius&quot;: 50}
#             );
#             marker_abed4b36223f95b3d9879f3b3d2c6812.setIcon(icon_fe85bc72dbb7fc705b8fdac787d42d13);
#
#
#             var marker_1b97ecee6bace0076c9b7d542501b136 = L.marker(
#                 [36.49344725, 36.3526944],
#                 {}
#             ).addTo(map_e87c83ec0e6228061b971e6dce4f9889);
#
#
#             var icon_c37d2d0bcd73dd530987e198af3d8483 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;
