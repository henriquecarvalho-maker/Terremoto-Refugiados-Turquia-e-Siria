# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
sns.set_theme(style='darkgrid')
plt.rc('figure', figsize=(14, 6))

# %%
dados = pd.read_csv('dados/Registered Syrian Refugees by Date.csv', sep=';')
dados
# Out:
#            sep=   Unnamed: 1
# 0     data_date  individuals
# 1    2012-01-15         9500
# 2    2012-02-29        10658
# 3    2012-04-18        23955
# 4    2012-04-23        23702
# ..          ...          ...
# 638         NaN          NaN
# 639         NaN          NaN
# 640         NaN          NaN
# 641         NaN          NaN
# 642         NaN          NaN
#
# [643 rows x 2 columns]

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\henri\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\henri\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: numpy in c:\users\henri\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: jinja2>=2.9 in c:\users\henri\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in c:\users\henri\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\henri\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\henri\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Coordenadas dos pontos
lats = np.random.normal(36, 1, 100) # latitude
lons = np.random.normal(37, 1, 100) # longitude

# Cria um mapa centrado nas coordenadas médias
map = folium.Map(location=[np.mean(lats), np.mean(lons)], zoom_start=7)

# Adiciona marcadores para cada ponto
for lat, lon in zip(lats, lons):
    folium.Marker(location=[lat, lon]).add_to(map)

# Mostra o mapa
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41ac80977e1d061c40ed74f71fdfd446 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41ac80977e1d061c40ed74f71fdfd446&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41ac80977e1d061c40ed74f71fdfd446 = L.map(
#                 &quot;map_41ac80977e1d061c40ed74f71fdfd446&quot;,
#                 {
#                     center: [35.989514793232445, 37.209079810721875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_080529d9094607c2271331457d88c5b7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_805808aa8987b3138f783806f2a476a2 = L.marker(
#                 [37.85356049990804, 35.647526751487696],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_e5eadfc109c2f93be56f04658b85f07c = L.marker(
#                 [37.740910965621566, 36.638439136888316],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_7ff37f5bcd2508e6ba2820e04dd10e7c = L.marker(
#                 [36.00516285432354, 36.87108928624894],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_ccba3adaadd2004b3da2a410abe462ba = L.marker(
#                 [35.2275822344352, 38.3496490680065],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_9f77adfc16fdbaef75ab30943e29fc5e = L.marker(
#                 [34.87254399486527, 37.261080010374656],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_7d21cb51405470dfd608c753890603fa = L.marker(
#                 [36.87010936745661, 37.16943617624826],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_2c69861437e3ed32918334497ea8454f = L.marker(
#                 [35.300019724015655, 37.93967637878045],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_5a21443fb6957205c5f5b2ee7f0e4750 = L.marker(
#                 [35.73384420205011, 37.53612228669064],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_9a4fff34dda41ca14face3bd14c45c06 = L.marker(
#                 [37.74962919658439, 37.66641229419114],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_f7600bfd2e3c6d5cb2a1a81160826b30 = L.marker(
#                 [37.19933034868718, 38.05279296548538],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_9d8a6b2bce18639794f7ddd1e54a32a0 = L.marker(
#                 [37.32135334140753, 36.611542755498334],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_291d62ea70df0384e6e7791a47a0fa28 = L.marker(
#                 [36.97006881652875, 35.81880795949437],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_71338dcd7f8c0d71080ec22702786fac = L.marker(
#                 [35.850681054472, 35.94480612051892],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_d14323afa1b2dbfcb1365af70d5390bf = L.marker(
#                 [35.38302084573041, 34.27070092545949],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_b2f5eecd5f7ca7ca4165ac465d83257f = L.marker(
#                 [34.98481210260675, 36.6466149534891],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_dac479eb41b380220aaca179bf7d7c10 = L.marker(
#                 [35.69091046630425, 37.61361899816066],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_c22544aa210ae125f76c0e312f72985c = L.marker(
#                 [35.109667975384205, 38.52241839244834],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_fbb499dcddfe4d94f19b1ea1ad94d232 = L.marker(
#                 [35.65168285673176, 38.92796128144441],
#                 {}
#             ).addTo(map_41ac80977e1d061c40ed74f71fdfd446);
#
#
#             var marker_aa3a84b9fa37b23eebd746f1b7428a75 = L.marker(
#                 [35.951550946559095, 37.5080937096832],
#                 {}
#             ).addTo(map_41ac80977e

# %%
dados1= pd.read_csv('hotosm_tur_destroyed_buildings_polygons_csv.csv')
dados1
# Out:
#           osm_id building damage_date addr_street destroyed_building  \
# 0     1147164787      NaN  2023-02-06         NaN                yes
# 1     1147166052      NaN  2023-02-06         NaN                yes
# 2     1147170022      NaN  2023-02-06         NaN                yes
# 3     1147174340      NaN  2023-02-06         NaN                yes
# 4     1147174347      NaN  2023-02-06         NaN                yes
# ...          ...      ...         ...         ...                ...
# 3301  1139190966      NaN  2023-02-06         NaN                yes
# 3302  1139524307      NaN  2023-02-06         NaN                yes
# 3303  1139658748      NaN  2023-02-06         NaN                yes
# 3304  1139274714      NaN  2023-02-06         NaN                yes
# 3305  1138927169      NaN  2023-02-06         NaN                yes
#
#              source  addr_full      damage_event addr_city addr_housenumber  \
# 0     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 1     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 2     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 3     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# 4     CopernicusEMS        NaN  #TürkiyeEQ060223       NaN              NaN
# ...             ...        ...               ...       ...              ...
# 3301          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
# 3302          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
# 3303          cscrc        NaN  #TürkiyeEQ060223       NaN              NaN
# 3304          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
# 3305          cscrs        NaN  #TürkiyeEQ060223       NaN              NaN
#
#      name damage_type  longitude   latitude geom_type
# 0     NaN  earthquake  36.365865  36.472146   POLYGON
# 1     NaN  earthquake  36.352694  36.493447   POLYGON
# 2     NaN  earthquake  36.353101  36.491821   POLYGON
# 3     NaN  earthquake  36.358288  36.496162   POLYGON
# 4     NaN  earthquake  36.358789  36.496386   POLYGON
# ...   ...         ...        ...        ...       ...
# 3301  NaN  earthquake  36.630427  37.022934   POLYGON
# 3302  NaN  earthquake  36.629054  37.025857   POLYGON
# 3303  NaN  earthquake  36.629579  37.024958   POLYGON
# 3304  NaN  earthquake  36.631257  37.027352   POLYGON
# 3305  NaN  earthquake  36.630033  37.018256   POLYGON
#
# [3306 rows x 15 columns]

# %%
longi = dados1['longitude']
lati = dados1['latitude']

# %%
# Coordenadas dos pontos
lats = lati # latitude
lons = longi # longitude

# Cria um mapa centrado nas coordenadas médias
map = folium.Map(location=[np.mean(lats), np.mean(lons)], zoom_start=8)

folium.TileLayer('cartodbpositron').add_to(map)
folium.TileLayer('Stamen Terrain').add_to(map)
folium.TileLayer('stamentoner').add_to(map)

# Adiciona marcadores para cada ponto
for lat, lon in zip(lats, lons):
    folium.Marker(location=[lat, lon], icon=folium.Icon(color = "blue", radius=50, icon="flag")).add_to(map)

folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_967ca7d1c437b7bb2a6d4cc1874b9be4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_967ca7d1c437b7bb2a6d4cc1874b9be4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_967ca7d1c437b7bb2a6d4cc1874b9be4 = L.map(
#                 &quot;map_967ca7d1c437b7bb2a6d4cc1874b9be4&quot;,
#                 {
#                     center: [37.01835326421933, 36.818975096105696],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7836f557308520005900f20c3dd8c770 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_967ca7d1c437b7bb2a6d4cc1874b9be4);
#
#
#             var tile_layer_a796168199c1d84baad196dfd51c7991 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_967ca7d1c437b7bb2a6d4cc1874b9be4);
#
#
#             var tile_layer_95a587fc67726f5b5de8724c36707507 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_967ca7d1c437b7bb2a6d4cc1874b9be4);
#
#
#             var tile_layer_8b72020025303a648403a95e1dbde9c6 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_967ca7d1c437b7bb2a6d4cc1874b9be4);
#
#
#             var marker_ada2b459aaa640dc184703c589d4360b = L.marker(
#                 [36.4721463720923, 36.3658651662668],
#                 {}
#             ).addTo(map_967ca7d1c437b7bb2a6d4cc1874b9be4);
#
#
#             var icon_753fe00f00adf0c4da08f84433b9a298 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;radius&quot;: 50}
#             );
#             marker_ada2b459aaa640dc184703c589d4360b.setIcon(icon_753fe00f00adf0c4da08f84433b9a298);
#
#
#             var marker_afebcdaa6fcabd3247aae9172b0acb53 = L.marker(
#                 [36.49344725, 36.3526944],
#                 {}
#             ).addTo(map_967ca7d1c437b7bb2a6d4cc1874b9be4);
#
#
#             var icon_0f871b23e7d76f4ee5cbf4fe00b45835 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;
